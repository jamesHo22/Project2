# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import functions from the modsim.py module
from modsim import *

# %%
def make_system(twg, twc):
    """
    A function that returns a system object with a state called init
    The current system
    
    twg = Hot gas side local wall temperature
    twc = Coolant side local wall temperature
    tco = Temperature of Coolant Liquid (water)
    taw = Temperature of the hot combustion gases (K)
    hg = hot gas side heat transfer co-effficient = 2956
    k = thermal conductivity of Al 6061, W/(m*K)
    thickness = thickness of Al 6061 wall (m)
    hc = coolant side heat transfer co-efficient
    t_0 = intitial time 
    t_end = final time
    
    """
    system = System(init = State(twg = twg, taw = 3000, twc = twc, summ = 0),
                    hg = 2187,
                    k = 167 ,
                    thickness = .0238125,
                    hc = 32369,
                    q =  4905759, 
                    t_0 = 0,
                    t_end = 200)
    return system

# %%
def update_func(state,t,system):
    """Test update"""

    unpack(system)
    twg1, taw1, twc1, summ = state
    
    #dtwg = hg*(3000 - twg1)
    
    dtwg = hg*(taw1 - twg1)
    dtwc = (k/thickness)*(twg1 - twc1)
    #print(dtwc)
    #dtwc = (k/thickness)*(twg1 - twc1)
    #dtwc = (1000-200)*(twg1 - twc1)
    #dtco = (1000)*(twc1 - tco1)
    
    # Implement cooling equations. Cooling 
    taw1 -= dtwg * 0.00001
    twg1 += (dtwg - dtwc) * 0.00001
    twc1 += dtwc * 0.00001
    #twc1 += (dtwc - dtco) * 0.00001
    #tco1 += dtco * 0.00001
    summ = taw1 + twg1 + twc1
    return State(twg = twg1, taw = taw1, twc = twc1, summ = summ)

# %%
def run_simulation(system, update_func):
    """Runs a simulation of the system.
        
    system: System object
    update_func: function that updates state
    
    returns: TimeFrame
    """
    unpack(system)
    
    frame = TimeFrame(columns=init.index)
    frame.row[t_0] = init
    
    for t in linrange(t_0, t_end):
        frame.row[t+1] = update_func(frame.row[t], t, system)
    frame.index / 100
    return frame

# %%
def plot_results(twg, taw, twc, summ):

    plot(twg, '--', label='twg')
    plot(twc, '-', label='twc')
    #plot(tco, '-', label = 'tco')
    plot(taw, '-', label='taw')
    plot(summ, '-', label='Total Energy')
    decorate(xlabel='Time',
             ylabel='Heat')

# %%
system = make_system(0, 0)
# Out:
# init         twg        0
# taw     3000
# twc        0
# summ   ...
# hg                                                        2187
# k                                                          167
# thickness                                            0.0238125
# hc                                                       32369
# q                                                      4905759
# t_0                                                          0
# t_end                                                      200
# dtype: object

# %%
results = run_simulation(system, update_func)
plot_results(results.twg, results.taw, results.twc, results.summ)

# %%
results
# Out:
#          twg      taw      twc  summ
# 0          0     3000        0     0
# 1      65.61  2934.39        0  3000
# 2    125.184  2870.21  4.60131  3000
# 3    179.599  2807.34  13.0579  3000
# 4    229.602  2745.66  24.7377  3000
# 5    275.823  2685.07   39.105  3000
# 6    318.799  2625.49  55.7064  3000
# 7    358.986  2566.86  74.1574  3000
# 8     396.77   2509.1  94.1328  3000
# 9    432.478  2452.16  115.357  3000
# 10    466.39  2396.01  137.597  3000
# 11   498.741   2340.6  160.656  3000
# 12   529.733   2285.9  184.366  3000
# 13   559.537  2231.88  208.587  3000
# 14   588.297   2178.5    233.2  3000
# 15   616.138  2125.76  258.103  3000
# 16   643.164  2073.62  283.213  3000
# 17   669.464  2022.08  308.456  3000
# 18   695.115  1971.11  333.774  3000
# 19   720.181   1920.7  359.116  3000
# 20   744.719  1870.84  384.438  3000
# 21   768.775  1821.52  409.705  3000
# 22    792.39  1772.72  434.887  3000
# 23   815.598  1724.44  459.959  3000
# 24    838.43  1676.67    484.9  3000
# 25    860.91   1629.4  509.694  3000
# 26    883.06  1582.61  534.325  3000
# 27   904.901  1536.32  558.782  3000
# 28   926.447   1490.5  583.056  3000
# 29   947.713  1445.15  607.138  3000
# ..       ...      ...      ...   ...
# 171  2514.11 -1946.59  2432.48  3000
# 172  2519.01 -1957.22  2438.21  3000
# 173  2523.87 -1967.74  2443.87  3000
# 174  2528.67 -1978.15  2449.48  3000
# 175  2533.42 -1988.46  2455.04  3000
# 176  2538.13 -1998.66  2460.53  3000
# 177  2542.79 -2008.76  2465.98  3000
# 178   2547.4 -2018.76  2471.36  3000
# 179  2551.97 -2028.66  2476.69  3000
# 180  2556.49 -2038.46  2481.97  3000
# 181  2560.96 -2048.16   2487.2  3000
# 182  2565.39 -2057.76  2492.37  3000
# 183  2569.77 -2067.27  2497.49  3000
# 184  2574.11 -2076.68  2502.56  3000
# 185  2578.41 -2085.99  2507.58  3000
# 186  2582.66 -2095.21  2512.55  3000
# 187  2586.87 -2104.34  2517.46  3000
# 188  2591.04 -2113.37  2522.33  3000
# 189  2595.17 -2122.32  2527.15  3000
# 190  2599.25 -2131.17  2531.92  3000
# 191  2603.29 -2139.93  2536.64  3000
# 192  2607.29 -2148.61  2541.32  3000
# 193  2611.25  -2157.2  2545.94  3000
# 194  2615.18  -2165.7  2550.52  3000
# 195  2619.06 -2174.12  2555.06  3000
# 196   2622.9 -2182.45  2559.55  3000
# 197  2626.71 -2190.69  2563.99  3000
# 198  2630.47 -2198.86  2568.39  3000
# 199   2634.2 -2206.94  2572.74  3000
# 200  2637.89 -2214.94  2577.05  3000
#
# [201 rows x 4 columns]
